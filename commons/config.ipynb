# %%
S3_BUCKET = "tech-challenge-etl-153372322872-us-east-2-an"

S3_BASE_PATH = f"s3://{S3_BUCKET}"

RAW_PATH = f"{S3_BASE_PATH}/raw"
BRONZE_PATH = f"{S3_BASE_PATH}/bronze"
SILVER_PATH = f"{S3_BASE_PATH}/silver"
GOLD_PATH = f"{S3_BASE_PATH}/gold"

TS_ALUNO = "TS_ALUNO"
TS_ESTADO = "TS_ESTADO"
TS_ITEM = "TS_ITEM"
TS_MUNICIPIO = "TS_MUNICIPIO"
INDICADOR_MUNICIPIO = "FT_INDICADOR_MUNICIPIO"
FT_MACHINE_LEARNING = 'FT_MACHINE_LEARNING'
METAS_UF = "METAS/UF"
METAS_MUNICIPIO = "METAS/MUNICIPIO"
METAS_BR = "METAS/BRASIL"

CSV_OPTIONS = {
    "header": "true",
    "inferSchema": "true",
    "sep": ";",
    "encoding": "ISO-8859-1"
}
