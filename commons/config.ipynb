# %%
"""
Configurações gerais do projeto
"""

# ==========================
# AWS / S3
# ==========================

S3_BUCKET = "tech-challenge-etl-153372322872-us-east-2-an"

BRONZE_PATH = f"s3://{S3_BUCKET}/bronze"
SILVER_PATH = f"s3://{S3_BUCKET}/silver"
GOLD_PATH = f"s3://{S3_BUCKET}/gold"


# ==========================
# Unity Catalog
# ==========================

CATALOG = "workspace"

BRONZE_SCHEMA = "bronze"
SILVER_SCHEMA = "silver"
GOLD_SCHEMA = "gold"


# ==========================
# Arquivos
# ==========================

TS_ALUNO = "TS_ALUNO.csv"
TS_ESTADO = "TS_ESTADO.csv"
TS_ITEM = "TS_ITEM.csv"
TS_MUNICIPIO = "TS_MUNICIPIO.csv"


# ==========================
# Spark
# ==========================

CSV_OPTIONS = {
    "header": True,
    "inferSchema": True,
    "delimiter": ";"
}
